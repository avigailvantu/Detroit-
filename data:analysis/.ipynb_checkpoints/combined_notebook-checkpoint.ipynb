# %% [markdown]
# # Detroit Open Demolitions
# ### Public X Design Workshop, Detroit, Sep, 2018
# ### We are Avigail Vantu (avigailvantu@gmail.com) & Eitan Akman (eitanakman@gmail.com) and we are very excited to be in Detroit. We came here from Brooklyn to talk about the intersection of urban design, open data, and technology.

# %% [markdown]
# # To access this notebook:
# # 1. Go to this URL: ***********
# # 2. Wait to be assigned a "student number"
# # 3. Password: pxd2018

# %% [markdown]
# ## Agenda:
#     1. Introduction:
#         a. Workshop Objectives
#         b. Intro to Open Data, Jupyter, and Python
#     2. Demolitions Data
#     3. Measuring the Impact of Demolitions
#         a. Crime
#         b. Real Estate
#     5. Conclusions / Discussion
#     6. * Extra: 311 data

# %% [markdown]
# Workshop objectives:
# In this hands-on workshop, participants will have the opportunity to map and quantify how demolition policies have impacted Detroit’s public spaces as well as how they are perceived.
#
# Core questions:
#
# 1. What are the monetary implications of the demolition policies?
# 2. How have the demolition policies influenced Deroit's communities?
# 3. Is there any evidence that the demolition policies have helped solve pressing issues such as crime levels and instability in real estate prices?

# %%
# Demolitions in Detroit colored by Neighborhoods
from IPython.display import Image
Image(filename='TotalDemoPerNighDetroit.png')

# %% [markdown]
# ## 1. Intro

# %% [markdown]
# # Python & Jupyter Notebooks

# %% [markdown]
# ## Jupyter what?!

# %% [markdown]
# Jupyter Notebooks is a popular interactive coding web application used by data scientists and programmers. If you're reading this, you're currently inside an Jupyter Notebook file. Notebook files consist of cells. You can navigate from cell to cell using the up and down arrow keys. Give it a try!

# %% [markdown]
# ## What do I mean when I say *interactive coding tool*?

# %% [markdown]
# Most computer programs are static in nature. They generally consist of a set of predefined steps which are stored in a text file on a computer. As needed, the contents of the file are fed to the **interpreter** -- the program which turns code into computer instructions (more on this later) -- and are executed as a unit. Here's an example of what a typical Python file looks like:
#
# ```
# # my_program.py
#
# x = "Hello, World!"
# print(x)
# ```
#
# The above program consists of three steps. The first line `# my_program.py` is what's called a <strong>*comment*</strong>. In Python, any line prefaced with a `#` is a comment and is ignored. In other words, the first line is the name of the file. It is purely stylistic and has no effect on the behavior of the program itself.
#
# The next step, `x = "Hello, World!"`, is a bit more interesting. In this case, the program is instructing the computer to create a reference, `x`, to some chunk of memory and to store inside that chunk of memory the **string** "Hello, World!".
#
# Finally, the last step, `print(x)`, instructs the computer to <strong>*invoke*</strong> (or call) a **function** called `print` with an **argument** (or input) of `x`. `print` is another program built-in to python that accepts an input and prints it to the screen.
#
# The cell below is meant to demonstrate how this program would run. Give it a try!

# %%
# run me by pressing shift + enter

x = "Hello, World!"
print(x)
# Out:
# Hello, World!

# %% [markdown]
# This style of programming is perfectly fine when the result of a program is determined by an unchanging set of rules. The static file approach however is NOT well-suited for all use cases. When performing data analysis using Python for example, the steps can't always be determined ahead of time. Datasets come in all different shapes and sizes, often require various unpredictable preprocessing steps (AKA <strong>*wrangling*</strong>) before they can be worked with.
#
# This is where Jupyter Notebooks comes in to the picture. As you can see, a Jupyter Notebook file is comprised of cells; each one building upon the last. It's almost as if the creators of Jupyter built-in a pause, fast-forward, and rewind button into your program. At anytime you can add cells to the end beginning or in-between. So in our Jupyter Notebook our old program could be written like this:

# %%
x = "Hello, World!" ## <--- Try changing the value in-between the quotes and then run the cells again

# %%
print(x)
# Out:
# Hello, World!

# %% [markdown]
# ### Here are some additional navigation and troubleshooting tips for Jupyter Notebooks

# %%
Image(filename='jupyter_menu.jpg')

# %% [markdown]
# - 1 saves your work similiar to other types of docs
# - 2 is used to add a new IN cell
# - If you make a mistake or just don't need a specific cell anymore, press 3 to crop it. Be careful to not click it by accident when trying to add a cell..
# - 4 shifts the chosen cell one spot higher in your notebook and 5 does the same but downward
# - 6 is used to run the chosen cell, this will genenrate the cell's output
# - 7 is used to change a cell's functionality, the two main ones we will use today is: code (default) and Markdown which is mainly used to write comments and titles.
#
# #### More to know
#
# - if the notebook is stuck, or if you want to restart it - go to 'Kernel' and click - 'Restart'
# - if you only want to run parts of the notebook - go to 'Cell' and choose the most suitable options: (Run All, Run All Above and Run All Bellow are some of the popular ones).
# - To save a copy of your work, go to File - Download As : we recommend HTML or IPYNB to restore with visualizations
# - To run a cell using only the keyboard press shift-return at the same time.

# %% [markdown]
# ## Python you'll need to know for this workshop
# - *variables*
# - *objects & types*
# - *functions*
# - *import statements & dependencies*

# %% [markdown]
# ### Variables
# As mentioned earlier, a variable is simply a reference to some chunk of memory. Every variable has a name and using that name, we can interact with the aformentioned chunk of memory; we can store things, modify things, and access what we've stored and/or modified using variables. Below are all examples of variables:

# %%
a = "my variable"
b = 12
c = 15.29034
d = [1, 'hello', 3.456]
e = {"hello": 3}

# %% [markdown]
# ### Objects & Types
# In Python, everything is an <strong>*object*</strong>. It's not terribly important for now to fully understand what an object is, but suffice it to say, an object is the most basic unit of Python thing (lol!) and everything is an object of some <strong>*type*</strong>. Different types of objects have different characteristics. This is also something we need not fully understand for now. Just acknowledging that there are differences is perfectly sufficient for our purposes. Below are some examples of object types. In the below examples we make use of a <strong>*function*</strong> (more on this shortly) called `type`, which simply takes an object and returns the object's type. Have a look:

# %%
type("my name is Eitan") # <--- anything w/ double quotes is a string.
# Out:
# str

# %%
type('1,000,000') # <--- single quotes work too.
# Out:
# str

# %%
type(143099) # <--- Numbers without quotes and decimals are called integers.
# Out:
# int

# %%
type(c) # we defined the variable c a few cells back. It's type is called a float.
# Out:
# float

# %%
type([1, 2, "three"]) # <--- square braces == list
# Out:
# list

# %%
type({"one": 1}) # <--- curly braces == dictionary
# Out:
# dict

# %% [markdown]
# ### Functions
# In our last few examples we made use of a function called `type`, but what is a function? One of the fundamental rules of programming is D.R.Y or Don't Repeat Yourself. Functions allow us take a complex set of commands which we don't want write over and over again, assign them name (another form of a variable FYI), and reuse as needed. This makes our programs more readable and can also abstract away some of the unimportant details. Functions can optionally accept arguments. Many functions, such as `type`, are built-in Python's standard libraries, but we can define our own as well as make use of third-party defined functions.
#
# In the below example I've defined a function called `titleize`, which given a title will capitalize the first letter of each word. As you can see the logic I use to accomplish this is complex enough that I wouldn't want to have to re-write it over and over again. Instead I can reuse the function I've defined over and over again as needed. Give it a try:

# %%
def titleize(title):
    return " ".join([x[0].upper() + x[1:] for x in title.split()])

# %%
print(titleize("to kill a mockingbird"))
print(titleize("catcher in the rye"))
print(titleize("war and peace"))
# Out:
# To Kill A Mockingbird
# Catcher In The Rye
# War And Peace

# %% [markdown]
# ### Import Statements & Dependencies
# Probably the coolest thing about Python is that it was designed such that it easily integrates with third-party software also referred to as <strong>*packages*</strong> and <strong>*libraries*</strong>. Indeed there are thousands of community-driven packages which programmers and data scientists rely on to do their work. We will be making use of a few such packages in our workshop today.
#
# Here are two examples of how one would add a package to their project:
#
# ```
# import some_package1
# import some_package2 as sp2
# ```
#
# In the first example we simply import (or add to our project) a package called `some_package1`. We now have full access to all the functionality bundled inside `some_package1`; it's essenstially as though we copied and pasted all of the code from `some_package1` into our project.
#
# The second example is much the same except in the case we <strong>*alias*</strong> our package using the `as` keyword to `sp2`. So here again we have full access to the package `some_package2`, but instead of using the full name we use `sp2` for ease of typing.

# %% [markdown]
# ### Recap
# Now I'll show you a quick example of all the things we learned. We'll start by importing a package called `pandas`, which is used to interact with data and which we will be using extensively today. Then I'll show you how to make use of pandas' funtionality.

# %%
## importing a package called pandas
import pandas as pd

# %% [markdown]
# ### A Note About CSV Files
# In the workshop today, the datasets will mainly come in the form of CSV files. CSV stands for Comma Separated Values. A CSV file is essentially a simplified spreadsheet except that the columns are delimited by commas and the rows by newlines.

# %%
# This sort of what a CSV file looks like
raw_data = """
first_name,last_name,age
Albert,Johnson,31
Emily,Smith,29
James,Allen,37
Judith,Bridges,33
"""

# %%
# This Function Is Unimportant
def unimportant_function(raw_data):
    from io import StringIO
    return StringIO(raw_data)

# %%
### Process Our Mock Data
data = unimportant_function(raw_data)

### Create Python object for data interaction
df = pd.read_csv(data)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#   first_name last_name  age
# 0     Albert   Johnson   31
# 1      Emily     Smith   29
# 2      James     Allen   37
# 3     Judith   Bridges   33

# %%
df['age'].max()
# Out:
# 37

# %% [markdown]
# ### 2 minutes about Open Data:

# %% [markdown]
# * What's open data? Who can use it?
# * Why is it so cool?
# * Detroit's open data portal https://data.detroitmi.gov/

# %% [markdown]
# ## 3.  Demolitions Data

# %%
#import packages

import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Read datasets

# %%
#load Demolitions data 
demolitions = pd.read_csv('Detroit_Demolitions.csv')

# %% [markdown]
# #### Insights From Data Exploration:
# Total number and cost of demolitions

# %%
#how many demolitions over the years 2014-2018
print ("The total number of demolitions is:",len(demolitions))
# Out:
# The total number of demolitions is: 14524

# %%
# calculate total cost of demolitions
print ("The total price of demolitions is ~$" + str(int(demolitions['Price'].sum() / 1000000))+"M")
# Out:
# The total price of demolitions is ~$228M

# %%
#group by neighborhoods to have the total price for demolitions for each
dem = demolitions.groupby(['Neighborhood']).sum()

# %%
#data cleaning and sorting
def my_demolition_cleaning_function(dem):
    del dem['Council_District']
    del dem['Latitude']
    del dem['Longitude']
    

#run the cleaning function  
my_demolition_cleaning_function(dem) 

#now let's sort the data so that the lowest priced neighborhood will apear first

# %% [markdown]
# This dataframe sums up all numerical columns (price, council district, Lat, Lon). However, except for price, all columns aggregated this way actually have no meaning. They are what's called <strong>*noise*</strong> and it's actually best to remove them from the data.
# Let's do that:

# %%
# In a DataFrame the "index" is a special column with special characteristics
# To make it easier to interact with, let's copy the information from the index and create a new "normal" column
dem['Neighborhood'] = dem.index
dem = dem.sort_values(by='Price')
# dem is a DF with USD spent on demolitions by neighborhood 
#let's see how does it looks like
dem.head(4)
# Out:
#                        Price         Neighborhood
# Neighborhood
# Greenwich             9310.0            Greenwich
# Green Acres          13726.0          Green Acres
# McNichols Evergreen  13900.0  McNichols Evergreen
# Rivertown            16550.0            Rivertown

# %% [markdown]
# Let's try to better understand the cost of demolitions by neighborhood.

# %%
print ("Bottom four Detroit neighborhoods in terms of total $ spent on demolitions:",dem.head(4))
print ("Bottom four Detroit neighborhoods in terms of total $ spent on demolitions:",dem.tail(4))
# Out:
# Bottom four Detroit neighborhoods in terms of total $ spent on demolitions:                        Price         Neighborhood
# Neighborhood
# Greenwich             9310.0            Greenwich
# Green Acres          13726.0          Green Acres
# McNichols Evergreen  13900.0  McNichols Evergreen
# Rivertown            16550.0            Rivertown
# Bottom four Detroit neighborhoods in terms of total $ spent on demolitions:                         Price       Neighborhood
# Neighborhood
# Claytown           6096510.79           Claytown
# Dexter-Linwood     6328961.55     Dexter-Linwood
# Holcomb Community  6897702.58  Holcomb Community
# Warrendale         9494484.32         Warrendale

# %%
# The most money for demolitions was spent in Warrendale :$9,494,484 Millions
dem[dem['Price'] ==9494484.319999998]
# Out:
#                    Price Neighborhood
# Neighborhood
# Warrendale    9494484.32   Warrendale

# %% [markdown]
# More than 9 Million USD were spent on demolitions in the neoghborhood of Warrendale, and only 9,000 USD were spent in Greenwich

# %% [markdown]
# #### Your turn --
# ### Task I:
# Can you calculate the mean cost of demolitions per neighborhood?

# %% [markdown]
# Hint 1: use "dem" as your work dataframe, "Price" is the column which we want to derive the mean from
#
# Hint 2: you may want to use this function: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.mean.html

# %%
# <your code>

# %% [markdown]
# Where within Detroit did the demolitions take place?
#
# ### Find Number of Demolitions per Neighborhood

# %%
#Aggregate number of demolitions by neighborhood 

demolitionsnum = demolitions.groupby(['Neighborhood']).count()

# %%
# re-organize DataFrame for count per neigh
def my_demolition_organize_function(demolitionsnum):
    # recreate a the neighborhood column
    demolitionsnum['Neighborhood'] = demolitionsnum.index
    # rename column
    demolitionsnum['DemCount'] = demolitionsnum['Address']
    
    

my_demolition_organize_function(demolitionsnum)

# %%
# remove all columns but the relevant ones
demolitionsnum = demolitionsnum[['Neighborhood','DemCount']]
# and display our re-organized dataframe
print (demolitionsnum.head())
# Out:
#                       Neighborhood  DemCount
# Neighborhood
# Airport Sub            Airport Sub       218
# Aviation Sub          Aviation Sub         4
# Bagley                      Bagley        10
# Barton-McFarland  Barton-McFarland       192
# Belmont                    Belmont         8

# %%
# The neighborhood where the most demolitions took place was Warrendale - 653
print ( "The neighborhood with the highest number of demolitions is", demolitionsnum[demolitionsnum['DemCount'] ==653])
# Out:
# The neighborhood with the highest number of demolitions is              Neighborhood  DemCount
# Neighborhood
# Warrendale     Warrendale       653

# %% [markdown]
# ### Make it relative: count demolitions by the size of  a given neighborhood

# %%
#to get size of neighborhood load neighborhoods ploygons which have acres attribute
DetroitNeighborhoods = gpd.read_file('DetroitNeighborhoods.geojson')

# %%
#re-organize data: 


# 1. unify column name 
DetroitNeighborhoods['Neighborhood'] = DetroitNeighborhoods['new_nhood']
# 1. only leave neighborhood and area: 
DetroitNeighborhoods = DetroitNeighborhoods[['Neighborhood','acres']]

# merge
Demolition_Area = pd.merge(DetroitNeighborhoods,  demolitionsnum, on = 'Neighborhood', how = "inner")

# convert data type to float to avoid issues manipulating later
Demolition_Area['acres'] = (Demolition_Area['acres']).astype('float64')



#see how it looks like
print (Demolition_Area.head())
# Out:
#          Neighborhood        acres  DemCount
# 0            West End  1086.498842       194
# 1       Chandler Park   496.783595        98
# 2           Riverbend  1159.775632       131
# 3  Jefferson Chalmers   901.711919       189
# 4         Morningside   964.174072       315
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2961: FutureWarning: 'Neighborhood' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Normalize calculate per number of demolitions / area * 1000  
Demolition_Area['normalized_demo'] = ((Demolition_Area['DemCount'] /  Demolition_Area['acres'])*1000)
# see how it looks like: 
Demolition_Area.head()
# Out:
#          Neighborhood        acres  DemCount  normalized_demo
# 0            West End  1086.498842       194       178.555183
# 1       Chandler Park   496.783595        98       197.268994
# 2           Riverbend  1159.775632       131       112.952882
# 3  Jefferson Chalmers   901.711919       189       209.601311
# 4         Morningside   964.174072       315       326.704491

# %% [markdown]
# #### "normalized_demo" is the number of demolitions per 1000 acres

# %% [markdown]
# #### Sort by # of Demolitions & Plot

# %%
#Let's sort and plot demolitions by neighborhood

# sort: 
Demolition_Area = Demolition_Area.sort_values(by='normalized_demo')

#plot : figure size, and then define which data are we ploting 

ax = Demolition_Area.plot.bar(x='Neighborhood', y='normalized_demo',figsize=(18,10))
plt.title('Detroit neighbohorhoods most number of demolitions by area',  fontsize=20)

plt.show()

# %% [markdown]
# #### The (large) number of hoods make the bar looking very tiny and hard to derive information from.

# %%
#let's see how many neighborhoods we actually have 
len(Demolition_Area)
# Out:
# 173

# %% [markdown]
# Let's try and plot the top 20% which are 34 neighborhoods

# %%
# take 
Demolition_Area_tail = Demolition_Area.tail(34)
#view the hoods
Demolition_Area_tail.tail()
# Out:
#           Neighborhood       acres  DemCount  normalized_demo
# 106            Jamison  154.757930       111       717.249191
# 105     Wildemere Park  170.542736       124       727.090480
# 123  Gateway Community  180.011811       136       755.505983
# 148  Holcomb Community  632.622318       485       766.650157
# 16       Westwood Park  162.618412       159       977.749066

# %%
#plot top 34 

ax = Demolition_Area_tail.plot.bar(x='Neighborhood', y='normalized_demo',figsize=(22,13))
plt.title('Top 20%: Detroit neighbohorhoods most number of demolitions by area',  fontsize=23)
plt.show()

# %% [markdown]
# Westwood Park is the neighborhood most influenced by demolitions

# %% [markdown]
# ### Just for fun: Plot Demolitions

# %%
# Demolitions DF to GeoDF 

from shapely.geometry import Point

geometry = [Point(xy) for xy in zip(demolitions.Longitude, demolitions.Latitude)]
#remove unuseful column
demolitions = demolitions.drop(['Longitude', 'Latitude'], axis=1)
# set projection
crs = {'init': 'epsg:4326'}
#create a new DataFrame for the geo points     
gdf = gpd.GeoDataFrame(demolitions, crs=crs, geometry=geometry)
    
demolitions
# Out:
#                    Address     Parcel ID            Contractor Name  \
# 0              6754 W Fort     18000464.                    Smalley
# 1              5528 Martin     18011033.                    Smalley
# 2             4462 33rd St     16012357.            DMC Consultants
# 3        3100 E Seven Mile    13008335-9        Den-Man Contractors
# 4      26181 W Outer Drive     20018839.            DMC Consultants
# 5            8218 Edgewood     17001774.                 Gayanga Co
# 6            18656 Concord     15011139.                 Gayanga Co
# 7              19140 Rogge     15006493.                 Gayanga Co
# 8             13927 Sussex     22046847.                 Gayanga Co
# 9              1075 Coplin   21051808-11                    Homrich
# 10         14204 Linnhurst     21018449.            DMC Consultants
# 11         8435 Mt Elliott     13009675.                 Gayanga Co
# 12             4575 Joy Rd     14003378.          Adamo Group, Inc.
# 13            5034 Balfour     21067696.            DMC Consultants
# 14          211 Trowbridge     01003322.            Able Demolition
# 15         16700 Evergreen     22095679.            DMC Consultants
# 16            6349 Pilgrim     16007375.            Able Demolition
# 17            6345 Pilgrim     16007374.                    Homrich
# 18         18246 Kentfield     22100353.                        MCM
# 19            551 Chandler     03001994.             ABC Demolition
# 20           9191 Chrysler     05004025.                 Gayanga Co
# 21          1514 Hazelwood     06002161.        Den-Man Contractors
# 22           19965 Lumpkin     09015318.          Adamo Group, Inc.
# 23             19966 Omira     09022793.                 Gayanga Co
# 24       102 Cedarhurst Pl     01004886.          Adamo Group, Inc.
# 25             7044 Arcola     15002592.            Able Demolition
# 26             12399 Maine     09012846.          Adamo Group, Inc.
# 27          969 Adeline St     01007780.                    Smalley
# 28          19696 Riopelle    09018627-8          Adamo Group, Inc.
# 29          17215 Riopelle     09018932.            Able Demolition
# ...                    ...           ...                        ...
# 14494           7498 Wykes     18013342.                    Homrich
# 14495        1085 Waterman     18008230.                 Gayanga Co
# 14496        14581 Burt Rd     22107999.   Rickman Enterprise Group
# 14497           101 Blaine     02001314.            DMC Consultants
# 14498      15829 Livernois     16017858.            Able Demolition
# 14499  15703 W Grand River     22007091.   Rickman Enterprise Group
# 14500          9190 Philip     21060350.  RDC Construction Services
# 14501          5049 Casper     20006963.            Able Demolition
# 14502         6683 Gratiot     15000380.          Adamo Group, Inc.
# 14503    6731 E Seven Mile     15004966.          Adamo Group, Inc.
# 14504          4710 Martin     18010971.  RDC Construction Services
# 14505    7000 E Seven Mile     15004901.            Able Demolition
# 14506    7026 E Seven Mile  15004895-900            Able Demolition
# 14507     7402 W Jefferson     18000088.              1 Way Service
# 14508        7522 W Warren     18003585.              1 Way Service
# 14509          7704 W Fort   20001753-89              1 Way Service
# 14510         7800 Pierson  22106154.001            Futurenet Group
# 14511         800 Crossley     18009550.              1 Way Service
# 14512        8413 Thaddeus     20000638.                    Homrich
# 14513       13934 E Warren     21002478.   Rickman Enterprise Group
# 14514         5721 28th St     14011146.          Adamo Group, Inc.
# 14515       11733 Longacre     22070686.          Adamo Group, Inc.
# 14516      15830 Grayfield     22120367.          Adamo Group, Inc.
# 14517    11710 Asbury Park     22061185.          Adamo Group, Inc.
# 14518        14150 Dolphin     22114711.          Adamo Group, Inc.
# 14519        9415 Appoline    22021896-8          Adamo Group, Inc.
# 14520        1939 Clements     08004514.          Adamo Group, Inc.
# 14521         14832 Tuller     16026781.          Adamo Group, Inc.
# 14522      21400 Margareta     22015734.   Rickman Enterprise Group
# 14523         17294 Braile     22105360.   Rickman Enterprise Group
#
#            Price Primary Funding Source Demolition Date Commercial Building  \
# 0       23800.00                Non-HHF      07/19/2018                  No
# 1       18500.00                Non-HHF      07/11/2018                  No
# 2       17850.00                Non-HHF      07/23/2018                  No
# 3       54650.00                Non-HHF      04/30/2018                 Yes
# 4       14890.00                Non-HHF      04/17/2018                  No
# 5       10900.00                Non-HHF      04/05/2018                  No
# 6       13000.00                Non-HHF      03/29/2018                  No
# 7       15100.00                Non-HHF      03/29/2018                  No
# 8       14225.00                Non-HHF      02/19/2018                  No
# 9      183000.00                Non-HHF      07/12/2018                 Yes
# 10      33890.00                Non-HHF      03/07/2018                  No
# 11      32350.00                Non-HHF      07/10/2018                 Yes
# 12      33250.00                Non-HHF      03/01/2017                 Yes
# 13      14286.00                Non-HHF      09/01/2015                  No
# 14      15049.00                    HHF      09/10/2014                  No
# 15       7861.40                    HHF      06/03/2014                  No
# 16       7347.75                    HHF      07/09/2014                  No
# 17       9800.00                    HHF      05/17/2014                  No
# 18       9247.00                    HHF      09/18/2014                  No
# 19      16750.00                    HHF      08/01/2014                  No
# 20      17950.00                Non-HHF      04/24/2018                  No
# 21       4530.00                Non-HHF      01/23/2018                  No
# 22       6942.00                Non-HHF      11/14/2017                  No
# 23      16225.00                Non-HHF      02/23/2018                  No
# 24      28484.00                Non-HHF      11/15/2017                  No
# 25      11564.50                Non-HHF      12/14/2016                  No
# 26      15200.00                Non-HHF      05/16/2017                  No
# 27      10500.00                Non-HHF      07/03/2018                  No
# 28       1928.00                Non-HHF      11/13/2017                  No
# 29      13635.00                Non-HHF      11/06/2017                  No
# ...          ...                    ...             ...                 ...
# 14494   41000.00                Non-HHF      02/05/2016                  No
# 14495   14320.00                Non-HHF      06/29/2018                  No
# 14496    8990.00                Non-HHF      12/23/2015                  No
# 14497   10626.00                Non-HHF      07/10/2014                 Yes
# 14498   12072.03                Non-HHF      09/16/2015                 Yes
# 14499   24090.00                Non-HHF      09/24/2015                 Yes
# 14500    4890.00                Non-HHF      08/31/2015                  No
# 14501   18800.00                Non-HHF      10/02/2015                  No
# 14502   44451.79                Non-HHF      05/20/2014                 Yes
# 14503   13989.90                Non-HHF      04/25/2014                 Yes
# 14504    9800.00                Non-HHF      08/07/2015                  No
# 14505    4949.00                Non-HHF      07/01/2014                 Yes
# 14506   13544.10                Non-HHF      07/01/2014                 Yes
# 14507   24750.00                Non-HHF      06/10/2014                 Yes
# 14508   11800.00                Non-HHF      06/16/2014                 Yes
# 14509   12000.00                Non-HHF      07/23/2014                 Yes
# 14510  251550.00                Non-HHF      11/16/2014                 Yes
# 14511   28900.00                Non-HHF      06/16/2014                 Yes
# 14512   13500.00                Non-HHF      12/02/2015                  No
# 14513   73540.00                Non-HHF      11/25/2015                 Yes
# 14514   16079.00                Non-HHF      07/10/2015                  No
# 14515   11811.00                Non-HHF      07/31/2015                  No
# 14516   11327.00                Non-HHF      07/24/2015                  No
# 14517   10172.00                Non-HHF      08/03/2015                  No
# 14518    8731.00                Non-HHF      07/24/2015                  No
# 14519    9936.00                Non-HHF      08/07/2015                  No
# 14520   22363.00                Non-HHF      07/16/2015                  No
# 14521   12488.00                Non-HHF      07/17/2015                  No
# 14522   13760.00                Non-HHF      08/14/2015                  No
# 14523   14240.00                Non-HHF      08/13/2015                  No
#
#        Council_District             Neighborhood  \
# 0                     6                   Delray
# 1                     6                 Claytown
# 2                     6           Chadsey Condon
# 3                     3           Conant Gardens
# 4                     6                  Boynton
# 5                     3              Airport Sub
# 6                     3                    Grant
# 7                     3                  Nortown
# 8                     1       Cadillac Community
# 9                     4                Riverbend
# 10                    4               Mapleridge
# 11                    5              Airport Sub
# 12                    5          Petoskey-Otsego
# 13                    4              Morningside
# 14                    5        Gateway Community
# 15                    1      North Rosedale Park
# 16                    2     Fitzgerald/Marygrove
# 17                    2     Fitzgerald/Marygrove
# 18                    1        Holcomb Community
# 19                    5                North End
# 20                    5                North End
# 21                    5            Herman Kiefer
# 22                    3                    Nolan
# 23                    3                    Nolan
# 24                    2           Grixdale Farms
# 25                    3              Airport Sub
# 26                    3        Campau/Banglatown
# 27                    2                  Penrose
# 28                    3                    Nolan
# 29                    3         Cadillac Heights
# ...                 ...                      ...
# 14494                 6                  Midwest
# 14495                 6        Central Southwest
# 14496                 1               Brightmoor
# 14497                 5               Piety Hill
# 14498                 2     Fitzgerald/Marygrove
# 14499                 1   Greenfield-Grand River
# 14500                 4        Outer Drive-Hayes
# 14501                 6                 Claytown
# 14502                 5  Gratiot Town/Ketterring
# 14503                 3                  Nortown
# 14504                 6                 Claytown
# 14505                 3                    Grant
# 14506                 3                    Grant
# 14507                 6                   Delray
# 14508                 6                  Midwest
# 14509                 6                   Delray
# 14510                 7               Warrendale
# 14511                 6                   Delray
# 14512                 6                   Delray
# 14513                 4                Fox Creek
# 14514                 6                  Midwest
# 14515                 7             Plymouth-I96
# 14516                 1               Brightmoor
# 14517                 7             Plymouth-I96
# 14518                 1               Brightmoor
# 14519                 7         Barton-McFarland
# 14520                 2    Oakman Blvd Community
# 14521                 7                Chalfonte
# 14522                 1        Holcomb Community
# 14523                 1        Holcomb Community
#
#                                 Location                              geometry
# 0        location\n(42.304381, -83.1096)            POINT (-83.1096 42.304381)
# 1      location\n(42.338227, -83.132268)  POINT (-83.13226800000001 42.338227)
# 2      location\n(42.336451, -83.114124)          POINT (-83.114124 42.336451)
# 3      location\n(42.432757, -83.070501)  POINT (-83.07050100000001 42.432757)
# 4      location\n(42.259794, -83.165767)          POINT (-83.165767 42.259794)
# 5      location\n(42.397151, -83.018679)  POINT (-83.01867900000001 42.397151)
# 6      location\n(42.431061, -83.032382)          POINT (-83.032382 42.431061)
# 7      location\n(42.434496, -83.029394)          POINT (-83.029394 42.434496)
# 8       location\n(42.387598, -83.19536)  POINT (-83.19535999999999 42.387598)
# 9      location\n(42.371929, -82.950271)  POINT (-82.950271 42.37192899999999)
# 10     location\n(42.431093, -82.977034)          POINT (-82.977034 42.431093)
# 11      location\n(42.390193, -83.03771)           POINT (-83.03771 42.390193)
# 12     location\n(42.366871, -83.125826)          POINT (-83.125826 42.366871)
# 13     location\n(42.400554, -82.946743)  POINT (-82.94674300000001 42.400554)
# 14     location\n(42.390861, -83.083073)          POINT (-83.083073 42.390861)
# 15      location\n(42.411668, -83.23759)           POINT (-83.23759 42.411668)
# 16     location\n(42.407327, -83.141493)  POINT (-83.14149300000001 42.407327)
# 17     location\n(42.407328, -83.141381)  POINT (-83.14138100000001 42.407328)
# 18     location\n(42.423706, -83.241243)  POINT (-83.24124300000001 42.423706)
# 19     location\n(42.376805, -83.069219)  POINT (-83.06921899999999 42.376805)
# 20     location\n(42.388556, -83.070288)  POINT (-83.07028800000001 42.388556)
# 21     location\n(42.376375, -83.094722)  POINT (-83.09472199999999 42.376375)
# 22     location\n(42.441254, -83.081065)          POINT (-83.081065 42.441254)
# 23     location\n(42.440751, -83.095915)  POINT (-83.09591500000001 42.440751)
# 24      location\n(42.421587, -83.10404)           POINT (-83.10404 42.421587)
# 25     location\n(42.405504, -83.028992)          POINT (-83.028992 42.405504)
# 26      location\n(42.40818, -83.067803)           POINT (-83.067803 42.40818)
# 27     location\n(42.438254, -83.113684)  POINT (-83.11368399999999 42.438254)
# 28     location\n(42.439002, -83.086383)          POINT (-83.086383 42.439002)
# 29     location\n(42.419999, -83.086344)          POINT (-83.086344 42.419999)
# ...                                  ...                                   ...
# 14494   location\n(42.348636, -83.14159)  POINT (-83.14159000000001 42.348636)
# 14495  location\n(42.307595, -83.111026)          POINT (-83.111026 42.307595)
# 14496  location\n(42.394467, -83.247218)          POINT (-83.247218 42.394467)
# 14497  location\n(42.378703, -83.081223)  POINT (-83.08122299999999 42.378703)
# 14498   location\n(42.40803, -83.140823)           POINT (-83.140823 42.40803)
# 14499  location\n(42.393257, -83.200641)          POINT (-83.200641 42.393257)
# 14500  location\n(42.407302, -82.963044)          POINT (-82.963044 42.407302)
# 14501   location\n(42.33175, -83.139462)   POINT (-83.13946199999999 42.33175)
# 14502  location\n(42.369857, -83.021152)          POINT (-83.021152 42.369857)
# 14503  location\n(42.434049, -83.033275)          POINT (-83.033275 42.434049)
# 14504   location\n(42.33244, -83.127798)  POINT (-83.127798 42.33244000000001)
# 14505  location\n(42.433597, -83.031482)          POINT (-83.031482 42.433597)
# 14506  location\n(42.433605, -83.031106)  POINT (-83.03110600000001 42.433605)
# 14507   location\n(42.29461, -83.108858)           POINT (-83.108858 42.29461)
# 14508  location\n(42.345054, -83.144109)          POINT (-83.144109 42.345054)
# 14509  location\n(42.301423, -83.116905)          POINT (-83.116905 42.301423)
# 14510  location\n(42.349027, -83.243955)          POINT (-83.243955 42.349027)
# 14511   location\n(42.294206, -83.11116)           POINT (-83.11116 42.294206)
# 14512  location\n(42.292127, -83.118737)          POINT (-83.118737 42.292127)
# 14513  location\n(42.393915, -82.962244)          POINT (-82.962244 42.393915)
# 14514  location\n(42.347366, -83.115617)          POINT (-83.115617 42.347366)
# 14515  location\n(42.374245, -83.214857)  POINT (-83.21485699999999 42.374245)
# 14516  location\n(42.406134, -83.268973)          POINT (-83.268973 42.406134)
# 14517   location\n(42.37412, -83.206856)           POINT (-83.206856 42.37412)
# 14518  location\n(42.389021, -83.258604)  POINT (-83.25860400000001 42.389021)
# 14519   location\n(42.365443, -83.16948)  POINT (-83.16948000000001 42.365443)
# 14520  location\n(42.396611, -83.114405)          POINT (-83.114405 42.396611)
# 14521  location\n(42.398605, -83.146572)  POINT (-83.14657199999999 42.398605)
# 14522  location\n(42.425418, -83.253476)  POINT (-83.25347600000001 42.425418)
# 14523  location\n(42.417735, -83.245757)          POINT (-83.245757 42.417735)
#
# [14524 rows x 11 columns]

# %%
#plot
f, ax = plt.subplots(1,figsize = (15,16))
gdf.plot(c='c',marker='.',ax=ax, alpha=0.6)
plt.title('Detroit Demolitions Map',  fontsize=23)
plt.show()

# %% [markdown]
# ## 3. Demolitions impact
# #### How can we measure a certain policy's impact and inform ourselves, our community, and desicion makers?
#
#
# We want to learn more about how Detroit's neighborhoods were influenced by the demolition policy over time. As the policy was first introduced in 2014 and is still ongoing now, we'd need to evaluate impact by comparing a specific variable which might have been influnced in the period when the demolitions were conducted. We'd need to compare it to the same variable from before the demolitions (earlier than 2014).
#
# #### a. Crime
#
# Let's check out crime levels in Detroit's neighbohoods. We will use data from Detroit's open data portal which reflect all crime incidents for 2013 (to determine crime level baseline just before the policy was introduced) and 2017 (the most recent full year).
#
# Since the crime incidents open datasets have changes in format over time and since our lab has strict time constraints, and computation power limitations we have manipulated the 2013 and 2017 datasets ahead of time and combined them into one cleaned CSV file grouped by neighborhood.
#
# Note that in a perfect world we'd want to know all other variables are constant in order to make inferences about impact. That said, cities are comlex, living organisms and variables such crime can't always be isolated. Using some fancy statistics there is a way to get a more precise understanding of these issues. For the purpose of this workshop, we will do that more simply (which might exclude some consideration).
#
#
# ** If you are intrested to see the data cleaning process you can check out this repo
#
# https://github.com/avigailvantu/Detroit-prep
#
# *** The raw data icludes All Crime Incidents for 2013 and 2017 and is available here:
#
# https://data.detroitmi.gov/browse?q=crime&sortBy=relevance

# %%
#Loading Crime Data - number of incidents for 2013 and 2017 
DetCrime = pd.read_csv('DetCrime13_17.csv')

#clean duplicated column
del DetCrime['Unnamed: 0'] 
#show data
DetCrime.head(4)
# Out:
#          Neighborhood  Incidents17  Incidents13
# 0            West End          352          693
# 1       Chandler Park          346          405
# 2           Riverbend          487          675
# 3  Jefferson Chalmers          468          654

# %%
#plot crime: number of incidents for 2013 and 2017
DetCrime.plot(x="Neighborhood", y=["Incidents17", "Incidents13"], kind="bar", figsize=(30,13))

# %% [markdown]
# Calculate crime precentage change between 2013 and 2017

# %%
# to do so we will apply to formula:    (new year – old year)/old year and then multiply the reault by 100.

# In our case: (incidents 2017) minus (incidents 2013) divided by (incidents 2013) , and multiplaid by 100
DetCrime['P_ChangeC'] = ((DetCrime['Incidents17'] - DetCrime['Incidents13']) / (DetCrime['Incidents13'] )* 100)

#how does it look like:
DetCrime.head()
# Out:
#          Neighborhood  Incidents17  Incidents13  P_ChangeC
# 0            West End          352          693 -49.206349
# 1       Chandler Park          346          405 -14.567901
# 2           Riverbend          487          675 -27.851852
# 3  Jefferson Chalmers          468          654 -28.440367
# 4         Morningside         1102         1514 -27.212682

# %%
#Sort
DetCrime = DetCrime.sort_values(by='P_ChangeC')
#plot
DetCrime.plot(x="Neighborhood", y=["P_ChangeC"], kind="bar", figsize=(30,15))

# %% [markdown]
# What does this plot show us?

# %% [markdown]
# #### Merge crime with demolition data

# %%
# merge with demolition data and look into the top 20%

# %% [markdown]
# Basically each one of the columns reflects number of incidents since we applied a "count"

# %%
#dem2['NumDemolitions'] = dem2['Address']

# %%
# merge crime and demolition data 
DetCrimeFinal = pd.merge(DetCrime,  Demolition_Area , on = 'Neighborhood', how = "inner")
DetCrimeFinal.head()
# Out:
#       Neighborhood  Incidents17  Incidents13  P_ChangeC       acres  DemCount  \
# 0     Medbury Park           41          111 -63.063063   79.534606         2
# 1  Oakwood Heights           33           89 -62.921348  620.012210         2
# 2          Davison          324          756 -57.142857  645.631872       174
# 3    Herman Kiefer           83          173 -52.023121  161.591038        89
# 4          Jamison          138          281 -50.889680  154.757930       111
#
#    normalized_demo
# 0        25.146287
# 1         3.225743
# 2       269.503424
# 3       550.773118
# 4       717.249191

# %%
DetCrimeFinal = DetCrimeFinal.sort_values(by='P_ChangeC')

# %%
DetCrimeFinal.plot(x="Neighborhood", y=["P_ChangeC", "normalized_demo"], kind="bar", figsize=(30,15))
plt.title('Detroit Demolitions and Crime levels 13 to 17 (sorted by Crime)',  fontsize=23)
# Out:
# Text(0.5,1,'Detroit Demolitions and Crime levels 13 to 17 (sorted by Crime)')

# %%
DetCrimeFinal = DetCrimeFinal.sort_values(by='normalized_demo')

# %%
DetCrimeFinal.plot(x="Neighborhood", y=["P_ChangeC", "normalized_demo"], kind="bar", figsize=(30,15))
plt.title('Detroit Demolitions and Crime levels 13 to 17 (sorted by Demolitions)',  fontsize=23)
# Out:
# Text(0.5,1,'Detroit Demolitions and Crime levels 13 to 17 (sorted by Demolitions)')

# %% [markdown]
# ### b. Real Estate

# %% [markdown]
# Now let's look into Real Estate values. The estimated increase in value for *each* house within 500ft of a demolition is 4%. We will be using another open dataset provided by the city of Detroit: the Parcel Point Ownership which is a record of all parcels in Detroit and information about them such as size, ownership and more. We will be using this data to look at sale amounts. We filtered the data into two datasets:
#
# 1. parcels that were last sole during 2013
#
# 2. parcels that were sold in 2017.
#
# We did not use other parcels the were last sold in other years. Note that in a scenario where a parcel was sold once on 2013 and another time on 2017 it will only appear once in the data, since the data is only giving us the "last sale".
#
# The 2013 data consisted of 10,738 unique sales and the 2017 had 8,689 unique sales. Check out the notebook we used for this analysis here:
# https://github.com/avigailvantu/Detroit-prep/blob/master/Real_Estate_Detroit.ipynb
#
# Similiar to the crime data, we aggregated and averaged each neighbohood's sales amount for the two years.

# %%
#Load data:
ParcelSale = pd.read_csv('Sales13_17.csv')
#show data
ParcelSale.head()
# Out:
#    Unnamed: 0      Neighborhood  MeanSale17  MeanSale13
# 0           0       Airport Sub     28121.0     13773.0
# 1           1        Arden Park    244500.0     50000.0
# 2           2      Aviation Sub     41075.0     36986.0
# 3           3            Bagley     58610.0     32598.0
# 4           4  Barton-McFarland     32127.0     32816.0

# %%
#Plot data 
ParcelSale.plot(x="Neighborhood", y=["MeanSale17", "MeanSale13"], kind="bar", figsize=(35,13))

# %%
#remove outliers for plotting: 
ParcelSale = ParcelSale[ParcelSale["MeanSale17"]  < 1500000 ]
ParcelSale.plot(x="Neighborhood", y=["MeanSale17", "MeanSale13"], kind="bar", figsize=(35,13))

# %% [markdown]
# ## Housing Prices Calculate % Change

# %% [markdown]
# In order to try and make conclusions about the impact of the demolitions on parcel sales in Detroit, we want to clacluate % change, similrarly to how we worked with the crime data. Note that we are not adjusting sale rates to inflation and the fact that $X 4 years ago are worth less than $X today.
#
# ### Task 3:
# Your task is to calculate the precentage change from 2013 (baseline) to 2017 (most recent year)
# Hint 1: remember the formula we applied on crime:
#
# (new year – old year)/old year and then multiply the result by 100.
#
# In our case: (mean sale rate 2017) minus (mean sale rate 2013) divided by (mean sale rate 2013) , and multiplied by 100
#
# Hint 2: if you are stuck try going back to the crime % change calculation
#
# * use ParcelSale as your DataFrame

# %%
# <your code>

# %%
#can remove later

ParcelSale['P_ChangeR'] = ((ParcelSale['MeanSale17'] - ParcelSale['MeanSale13']) / (ParcelSale['MeanSale13'] )* 100)

#how does it look like:
ParcelSale.head()
# Out:
#    Unnamed: 0      Neighborhood  MeanSale17  MeanSale13   P_ChangeR
# 0           0       Airport Sub     28121.0     13773.0  104.174835
# 1           1        Arden Park    244500.0     50000.0  389.000000
# 2           2      Aviation Sub     41075.0     36986.0   11.055535
# 3           3            Bagley     58610.0     32598.0   79.796307
# 4           4  Barton-McFarland     32127.0     32816.0   -2.099586

# %% [markdown]
# #### Plot

# %%
## merge with demolitions and data and crime 
DetCrimeSale = pd.merge(DetCrimeFinal,  ParcelSale, on = 'Neighborhood', how = "inner")

DetCrimeSale.head()
# Out:
#           Neighborhood  Incidents17  Incidents13  P_ChangeC       acres  \
# 0          Green Acres          128          193 -33.678756  355.497459
# 1            Rivertown          432          671 -35.618480  352.337377
# 2  University District          291          465 -37.419355  323.024820
# 3      Oakwood Heights           33           89 -62.921348  620.012210
# 4   Milwaukee Junction          198          132  50.000000  252.586824
#
#    DemCount  normalized_demo  Unnamed: 0  MeanSale17  MeanSale13   P_ChangeR
# 0         1         2.812960          74    119340.0     53983.0  121.069596
# 1         1         2.838189         159    296091.0    504758.0  -41.340008
# 2         1         3.095737         176    234482.0     76946.0  204.735789
# 3         2         3.225743         137    747500.0    102207.0  631.358909
# 4         1         3.959035         115    453625.0    901760.0  -49.695595

# %%
#sort by % change in real estate $$ 
DetCrimeSale = DetCrimeSale.sort_values(by='P_ChangeR')
DetCrimeSale = DetCrimeSale[DetCrimeSale["P_ChangeR"]  < 1500 ]

# %%
DetCrimeSale.plot(x="Neighborhood", y=["P_ChangeR", "normalized_demo"], kind="bar", figsize=(30,15))
plt.title('Detroit Demolitions and Real Estate Sales levels 13 to 17 (sorted by Sales % change)',  fontsize=23)
# Out:
# Text(0.5,1,'Detroit Demolitions and Real Estate Sales levels 13 to 17 (sorted by Sales % change)')

# %%
#sort again by number of demolitions 
DetCrimeSale = DetCrimeSale.sort_values(by='normalized_demo')

# %%
#plot again:

DetCrimeSale.plot(x="Neighborhood", y=["P_ChangeR", "normalized_demo"], kind="bar", figsize=(30,15))
plt.title('Detroit Demolitions and Real Estate Sales levels 13 to 17 (sorted by normalized demolitions )',  fontsize=23)
# Out:
# Text(0.5,1,'Detroit Demolitions and Real Estate Sales levels 13 to 17 (sorted by normalized demolitions )')

# %% [markdown]
# ## 4. ?? 311 improve detroit demolitions related data

# %% [markdown]
# ### Task 4: individual exploration

# %% [markdown]
# ## 5. Conclusions / Discussion

# %% [markdown]
# Let's go back to our workshop objectives:
#
# 1. What are the monetary implications of the demolition policy?
# 2. How did the demolition policy influence Deroit's communities?
# 3. Is there an evidence that the demolition policy has helped solve pressing issues such as crime levels instability in real estate pricing?

# %% [markdown]
# To sum up:
# - cost
# - crime
# - real estate

# %% [markdown]
# ### More stuff you might want to know...

# %% [markdown]
# * If you want to expand your Jupyter and Pandas knowledge we recommend starting with :http://pandas.pydata.org/pandas-docs/version/0.15.2/tutorials.html
# * Important: To save your notebook to your local machine - go to: File- Download as - Choose HTML (or Notebook if you have Anaconda installed to your computer)
# * To access data used for this lab go to: https://data.detroitmi.gov/
# * If you are intrested in learning more about Detroit's demolitions and deepen your study using other cool datasets, we recommended analyzing the Demolition Pipeline data as well as the Upcoming Demolitions to learn where the next demolitions are planned to take place (both datasets can be accessed in Detroit's open data portal)
